# %% [raw]
# ---
# layout: post
# title: Data Abstraction Homework
# description: Quick practice with Javascript Lists
# permalink: /javascript/data-abstraction/collaborators-hw
# Author: Nitya R, Alice L, Brandon C
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>Data Abstraction Hack Homework</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       padding: 20px;
#       background-color: #000;
#       color: #f4f4f4;
#     }
#     h1 { color: #f39c12; }
#     h2 { margin-top: 30px; color: #1abc9c; }
#     .output {
#       background: #222;
#       padding: 15px;
#       border-radius: 8px;
#       color: #fff;
#     }
#     code, pre {
#       background: #333;
#       color: #0f0;
#       padding: 5px;
#       border-radius: 5px;
#     }
#     .instructions p, .instructions li {
#       color: #ffffff;
#     }
#     .hack-instructions p,
#     .hack-instructions ul,
#     .hack-instructions li {
#       color: #ffffff;
#     }
#   </style>
# </head>
# <body>
#   <h1>📝 Data Abstraction Hack (10 minutes)</h1>
#
#   <h2 class="instructions">Instructions</h2>
#   <div class="instructions">
#     <p>In this activity, you’ll learn how <strong>lists</strong> manage data and reduce complexity in programs. Follow these steps:</p>
#     <ol>
#       <li>Edit the <code>students</code> list to use your own names (friends, classmates, etc.).</li>
#       <li>Edit the <code>scores</code> list to assign each student a score of your choice.</li>
#       <li>Save and refresh the page in your browser to see how the output changes automatically.</li>
#       <li>After experimenting with <code>students</code> and <code>scores</code>, complete the 🚀 Hack Challenge at the bottom.</li>
#       <li>To make edits, open <strong>VS Code</strong> and find the file at <code>notebooks/csp/big-ideas/2025-09-26-bigidea32homework.ipymd</code>.</li>
#     </ol>
#   </div>
#
#   <h2>Class Roster Output:</h2>
#   <div id="output" class="output"></div>
#
#   <script>
#     // --- 1. Define lists ---
#     let students = ["Vivian", "Sarah", "Paul"];
#     let scores = [89, 20000, 78];
#
#     let out = "";
#
#     // --- 2. Print roster ---
#     out += "<p><strong>Students:</strong> " + students.join(", ") + "</p>";
#
#     // --- 3. Print first student and score ---
#     out += "<p><strong>First student:</strong> " + students[0] + " - " + scores[0] + "</p>";
#
#     // --- 4. Add a new student and score ---
#     students.push("Dana");
#     scores.push(95);
#     out += "<p><strong>After adding Dana:</strong> " + students.join(", ") + "</p>";
#
#     // --- 5. Remove a student who transfers out ---
#     let index = students.indexOf("Paul"); // assume Paul leaves
#     if (index !== -1) {
#       students.splice(index, 1);
#       scores.splice(index, 1);
#     }
#     out += "<p><strong>After removing Paul:</strong> " + students.join(", ") + "</p>";
#
#     // --- 6. Curve all scores by +5 ---
#     for (let i = 0; i < scores.length; i++) {
#       scores[i] += 5;
#     }
#
#     // --- 7. Print each student with score ---
#     out += "<h3>Final Scores</h3>";
#     for (let i = 0; i < students.length; i++) {
#       out += "<p>" + students[i] + " - " + scores[i] + "</p>";
#     }
#
#     // --- 8. Hack Challenge: create new list ---
#     let favoriteFoods = ["Sushi", "Falafal", "Hotdogs"];
#     out += "<h3>Favorite Foods</h3>";
#     for (let i = 0; i < favoriteFoods.length; i++) {
#       out += "<p>" + favoriteFoods[i] + "</p>";
#     }
#
#     // --- 9. Display output ---
#     document.getElementById("output").innerHTML = out;
#   </script>
# </body>
# </html>
